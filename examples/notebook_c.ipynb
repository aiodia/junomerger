# %%
import junomerger

# %%
#convert notebook to html
notebook_a = junomerger.convert_ipynb2html('notebook_a.ipynb')
notebook_b = junomerger.convert_ipynb2html('notebook_b.ipynb')

# %% [markdown]
# # PART A

# %%
#put notebook A explanation here
notebook_a.show_jupyter_output(keyword='a_explanation')
# Out:
# <div class="output_wrapper">
# <div class="output">
# <div class="output_area">
#
# <div class="output_subarea output_stream output_stdout output_text">
# <pre>notebook A explanation
# </pre>
# </div>
# </div>
# <div class="output_area">
#
# <div class="output_html rendered_html output_subarea ">
# <div style="display:none;">a_explanation</div>
# </div>
# </div>
# </div>
# </div>

# %%
#put notebook A result here
notebook_a.show_jupyter_output(keyword='a_result')
# Out:
# <div class="output_wrapper">
# <div class="output">
# <div class="output_area">
#
# <div class="output_html rendered_html output_subarea ">
# <div style="display:none;">a_result</div>
# </div>
# </div>
# <div class="output_area">
#
# <div class="output_png output_subarea ">
# <img src="data:image/png;base64,...
# ">
# </img></div>
# </div>
# </div>
# </div>

# %% [markdown]
# # PART B

# %%
#put notebook A explanation here
notebook_b.show_jupyter_output(keyword='b_explanation')
# Out:
# <div class="output_wrapper">
# <div class="output">
# <div class="output_area">
#
# <div class="output_subarea output_stream output_stdout output_text">
# <pre>notebook B explanation
# </pre>
# </div>
# </div>
# <div class="output_area">
#
# <div class="output_html rendered_html output_subarea ">
# <div style="display:none;">b_explanation</div>
# </div>
# </div>
# </div>
# </div>

# %%
#put notebook B result here
notebook_b.show_jupyter_output(keyword='b_result')
# Out:
# <div class="output_wrapper">
# <div class="output">
# <div class="output_area">
#
# <div class="output_html rendered_html output_subarea ">
# <div style="display:none;">b_result</div>
# </div>
# </div>
# <div class="output_area">
#
# <div class="output_png output_subarea ">
# <img src="data:image/png;base64,...
# ">
# </img></div>
# </div>
# </div>
# </div>

# %% [markdown]
# # Part C

# %%
print("conclusion")
# Out:
# conclusion
